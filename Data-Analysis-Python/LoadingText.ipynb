# %% [markdown]
# # 03_02: Loading Text Files

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
# iterating over an open file yields its lines, one by one

words = []
for line in open('words.txt', 'r'):
    words.append(line)

# %%
len(words)
# Out:
# 235886

# %%
words[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron\n'.strip().lower()
# Out:
# 'aaron'

# %%
words = []
for line in open('words.txt', 'r'):
    words.append(line.strip().lower())

# %%
words[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
words = set()
for line in open('words.txt', 'r'):
    words.add(line.strip().lower())

# %%
# a set comprehension that collects stripped and lowercased lines...
words = {line.strip().lower() for line in open('words.txt', 'r')}

# %%
words
# Out:
# {'proapproval',
#  'epochism',
#  'lophiodon',
#  'wirebird',
#  'ovisac',
#  'xenophile',
#  'donation',
#  'anticouncil',
#  'mashpee',
#  'misery',
#  'elfkin',
#  'woozy',
#  'lonchopteridae',
#  'nudeness',
#  'despotic',
#  'diphosphide',
#  'spiculigerous',
#  'mud',
#  'yahgan',
#  'ninepegs',
#  'scrunchy',
#  'highlandish',
#  'betallow',
#  'gentian',
#  'aeolid',
#  'nonangelic',
#  'diaphanotype',
#  'defenselessness',
#  'inobtrusiveness',
#  'slate',
#  'unobservant',
#  'balsamroot',
#  'nohuntsik',
#  'precorruptive',
#  'suberone',
#  'abampere',
#  'isohyet',
#  'wagnerize',
#  'synodal',
#  'pagiopod',
#  'pria',
#  'infracostal',
#  'obstetrist',
#  'patternmaker',
#  'semicompacted',
#  'astrogonic',
#  'cayenned',
#  'piceoferruginous',
#  'venipuncture',
#  'pendulation',
#  'honorability',
#  'undevotion',
#  'vaginoperineal',
#  'nutting',
#  'frondose',
#  'lepospondyli',
#  'nitrometer',
#  'landwhin',
#  'underbraced',
#  'valetdom',
#  'charites',
#  'polytrichaceous',
#  'ruing',
#  'commonize',
#  'beclasp',
#  'outsnatch',
#  'terron',
#  'ideation',
#  'deducibility',
#  'beatific',
#  'suffixal',
#  'dermatocele',
#  'redeposition',
#  'unavoidal',
#  'unthreaded',
#  'phrenogram',
#  'percarbonic',
#  'sonoran',
#  'bisontine',
#  'virginally',
#  'divorceable',
#  'obtect',
#  'weightedly',
#  'epimyth',
#  'bisnaga',
#  'perspirative',
#  'pincase',
#  'tabularly',
#  'maianthemum',
#  'midaxillary',
#  'labyrinthically',
#  'stemmer',
#  'stylo',
#  'monotrochous',
#  'precession',
#  'unrevengeful',
#  'buzzy',
#  'estruation',
#  'nonirritating',
#  'um',
#  'hestern',
#  'shadoof',
#  'dermatology',
#  'unsounded',
#  'shamanize',
#  'droseraceae',
#  'rabbonim',
#  'minkery',
#  'karyomiton',
#  'lierre',
#  'anniverse',
#  'rhythmal',
#  'nonimporting',
#  'panmug',
#  'carposporic',
#  'heterogametic',
#  'radiomicrometer',
#  'contrite',
#  'homotony',
#  'uzan',
#  'postnati',
#  'scribophilous',
#  'hippurate',
#  'unmeddlesome',
#  'monopody',
#  'antinarcotic',
#  'splendorous',
#  'proportionless',
#  'myoepithelial',
#  'putois',
#  'suggestionable',
#  'odontotrypy',
#  'plutarchy',
#  'fifteenfold',
#  'bicyanide',
#  'prefamiliar',
#  'hydrobates',
#  'procnemial',
#  'catchingness',
#  'museum',
#  'unrecompensable',
#  'disenthronement',
#  'bating',
#  'draftman',
#  'gyroplane',
#  'inconsecutive',
#  'superserious',
#  'unsubmitting',
#  'spiroloculine',
#  'upstep',
#  'author',
#  'artemisin',
#  'subiodide',
#  'scrupulousness',
#  'carpetmaking',
#  'tamulic',
#  'preguiltiness',
#  'skeppist',
#  'bisyllabism',
#  'rebaptize',
#  'burly',
#  'measuredly',
#  'landladyish',
#  'libertyless',
#  'strongyloplasmata',
#  'albedo',
#  'cupressaceae',
#  'ballata',
#  'lustring',
#  'theatergoer',
#  'dentation',
#  'norbert',
#  'hydrosilicate',
#  'provableness',
#  'exclusion',
#  'boud',
#  'misenroll',
#  'parallelable',
#  'salpidae',
#  'procuratorship',
#  'reroyalize',
#  'snaking',
#  'euphonia',
#  'dacryuria',
#  'attendance',
#  'pinguedinous',
#  'stauroscopically',
#  'multilinguist',
#  'gerrymander',
#  'anesthetist',
#  'bombycid',
#  'programmatic',
#  'anastasian',
#  'genny',
#  'reprehensibly',
#  'toxophilitic',
#  'horror',
#  'appreciator',
#  'nonpursuit',
#  'forsakenness',
#  'rootle',
#  'outraught',
#  'callitriche',
#  'cathode',
#  'tibiopopliteal',
#  'spinach',
#  'euonymus',
#  'steganophthalmatous',
#  'antimark',
#  'spatiation',
#  'cometology',
#  'orbitelarian',
#  'goosenecked',
#  'zavijava',
#  'necrobacillary',
#  'dubitatingly',
#  'fifthly',
#  'teamwork',
#  'multiflow',
#  'testibrachium',
#  'unsolidly',
#  'noncongratulatory',
#  'synergistically',
#  'scelalgia',
#  'articulability',
#  'oenanthylate',
#  'panary',
#  'semicirque',
#  'yazoo',
#  'cylindrocylindric',
#  'heterostatic',
#  'puppetly',
#  'autonomous',
#  'uncharm',
#  'flatfoot',
#  'electrocoagulation',
#  'accentually',
#  'cardiotomy',
#  'odorimeter',
#  'whicken',
#  'albumenizer',
#  'arock',
#  'halfheartedly',
#  'backrope',
#  'dramaturgic',
#  'swordstick',
#  'cirque',
#  'peritoneally',
#  'untrussed',
#  'intendible',
#  'aizoon',
#  'erosely',
#  'triflet',
#  'unlabialize',
#  'ironhanded',
#  'noctilionidae',
#  'obsignate',
#  'lophocomi',
#  'cephalotome',
#  'frigidness',
#  'furlable',
#  'craggan',
#  'prepenial',
#  'courtierly',
#  'oestriol',
#  'nontannic',
#  'blowiron',
#  'function',
#  'woundableness',
#  'lairdly',
#  'theologaster',
#  'whaleback',
#  'paleoclimatic',
#  'unfleece',
#  'dunst',
#  'exoascus',
#  'overfatigue',
#  'peloriate',
#  'courtier',
#  'parallelogrammatical',
#  'portraitlike',
#  'hexadactyly',
#  'mormondom',
#  'enwound',
#  'smellable',
#  'underrealm',
#  'choriocarcinoma',
#  'definiteness',
#  'hup',
#  'callant',
#  'sacculoutricular',
#  'prologuist',
#  'achakzai',
#  'pycnonotinae',
#  'valvula',
#  'weinschenkite',
#  'existence',
#  'rhomboidally',
#  'embow',
#  'casemate',
#  'fremontodendron',
#  'rustlingly',
#  'unsex',
#  'tenontagra',
#  'carpocratian',
#  'ideogenetic',
#  'loosing',
#  'mythometer',
#  'zelatrice',
#  'enamorment',
#  'florisugent',
#  'miniver',
#  'colorlessly',
#  'rytidosis',
#  'caddow',
#  'thaumaturgist',
#  'rafter',
#  'reforecast',
#  'nonsectorial',
#  'gooma',
#  'lienee',
#  'malchite',
#  'xenomorphic',
#  'falisci',
#  'aramidae',
#  'runiform',
#  'renderer',
#  'symbiotically',
#  'boce',
#  'halibios',
#  'lithoglyptics',
#  'archival',
#  'competitory',
#  'sabbatical',
#  'songbird',
#  'photophony',
#  'physicogeographical',
#  'flimsily',
#  'they',
#  'sylphic',
#  'intermolecular',
#  'semiball',
#  'gloam',
#  'snubbish',
#  'meningococcic',
#  'barothermograph',
#  'herring',
#  'ketting',
#  'faustian',
#  'balatronic',
#  'nonbitter',
#  'sahh',
#  'allthorn',
#  'hearthwarming',
#  'choroidoiritis',
#  'bridleman',
#  'disturbative',
#  'proecclesiastical',
#  'crebricostate',
#  'subchaser',
#  'apyretic',
#  'basigynium',
#  'fernery',
#  'gunstone',
#  'recelebrate',
#  'mandarinate',
#  'randan',
#  'preparoccipital',
#  'magiric',
#  'calamariaceae',
#  'webwork',
#  'mongol',
#  'subultimate',
#  'hydrocele',
#  'satyress',
#  'menostatic',
#  'baseborn',
#  'defeatism',
#  'foresee',
#  'wifeward',
#  'parasyphilis',
#  'croup',
#  'unbolled',
#  'copaene',
#  'bionomically',
#  'psychurgy',
#  'emydea',
#  'nonrectified',
#  'dactylioglyph',
#  'gimlet',
#  'arizona',
#  'wrongdoing',
#  'pedatilobate',
#  'yirm',
#  'entozoology',
#  'spaniellike',
#  'irrepressibly',
#  'superlie',
#  'postvelar',
#  'studding',
#  'tephillin',
#  'tyrrhene',
#  'entophytically',
#  'unfertile',
#  'coracoclavicular',
#  'nonforfeiture',
#  'carpophyll',
#  'gravimetric',
#  'fissilinguia',
#  'tashnakist',
#  'abaze',
#  'furrily',
#  'pantile',
#  'hemoglobinometer',
#  'panlogistical',
#  'hipping',
#  'portentous',
#  'treat',
#  'preadmonition',
#  'castellany',
#  'unsinkable',
#  'undreading',
#  'egomaniac',
#  'animalian',
#  'resistlessly',
#  'ceratiid',
#  'apar',
#  'physiosophy',
#  'aphidicolous',
#  'byword',
#  'upcity',
#  'orlo',
#  'bozal',
#  'underswamp',
#  'exaggerator',
#  'campion',
#  'polymorphous',
#  'tauricornous',
#  'unengraved',
#  'jovialty',
#  'caractacus',
#  'orogeny',
#  'typhlopid',
#  'electrocatalysis',
#  'federal',
#  'musciform',
#  'poppyfish',
#  'prefeudalic',
#  'brilliancy',
#  'azonium',
#  'myelonic',
#  'bedstaves',
#  'euhedral',
#  'prudent',
#  'scringe',
#  'mahomet',
#  'autoinhibited',
#  'ramaism',
#  'lobola',
#  'griffe',
#  'detainingly',
#  'bridleless',
#  'babuism',
#  'telangiosis',
#  'balladize',
#  'catachrestically',
#  'vermeil',
#  'outpour',
#  'interviewable',
#  'tripletail',
#  'buduma',
#  'chaperonless',
#  'pantelegraph',
#  'direction',
#  'perinephrium',
#  'zygnemales',
#  'strangler',
#  'messagery',
#  'honest',
#  'tackless',
#  'arches',
#  'syngnathus',
#  'reforgive',
#  'untallied',
#  'unexercisable',
#  'decarbonize',
#  'herd',
#  'aerophile',
#  'preallot',
#  'softship',
#  'frightable',
#  'semicured',
#  'brideknot',
#  'blennuria',
#  'guiltlessly',
#  'pastinaca',
#  'ulotrichi',
#  'rotalia',
#  'cnidoscolus',
#  'scrupulous',
#  'arthragra',
#  'inconfusedly',
#  'lipan',
#  'nimbi',
#  'vauntery',
#  'enochic',
#  'pothanger',
#  'metapectic',
#  'rewish',
#  'showworthy',
#  'borofluoride',
#  'boarwood',
#  'labioglossopharyngeal',
#  'unthorny',
#  'rullion',
#  'mittimus',
#  'undoubtedness',
#  'ungirdled',
#  'tunebo',
#  'underplain',
#  'toughly',
#  'browed',
#  'hemangiosarcoma',
#  'verticity',
#  'outslang',
#  'oversave',
#  'priacanthid',
#  'binukau',
#  'metamorphoses',
#  'hydrophthalmus',
#  'marbler',
#  'karyoplasm',
#  'inky',
#  'praisable',
#  'peachblow',
#  'purchasability',
#  'pinguefy',
#  'trachealgia',
#  'recomputation',
#  'theogony',
#  'octapla',
#  'tenodynia',
#  'infinitesimalness',
#  'burl',
#  'inconsolableness',
#  'rebudget',
#  'overexcite',
#  'untradesmanlike',
#  'obtrusively',
#  'deathling',
#  'transmigrant',
#  'longingly',
#  'occasionless',
#  'dissightly',
#  'neurotically',
#  'neuralist',
#  'unpejorative',
#  'unthinkingly',
#  'grottolike',
#  'microspectroscope',
#  'coronership',
#  'cogonal',
#  'lepidoid',
#  'calcariform',
#  'palisander',
#  'anthropogeographical',
#  'bespot',
#  'travis',
#  'beset',
#  'beshlik',
#  'stepmotherhood',
#  'limoid',
#  'lungis',
#  'nubby',
#  'slumpy',
#  'ashkenazic',
#  'malasapsap',
#  'actomyosin',
#  'interdiction',
#  'parentality',
#  'sawfly',
#  'sublime',
#  'kjeldahlize',
#  'plagioclasite',
#  'stranger',
#  'virusemic',
#  'ossification',
#  'labyrinthibranchiate',
#  'subsumptive',
#  'overimaginativeness',
#  'haaf',
#  'deathlessness',
#  'priesteen',
#  'warcraft',
#  'spiralism',
#  'woodroof',
#  'predispute',
#  'undepurated',
#  'paganically',
#  'polytheist',
#  'expectorator',
#  'strident',
#  'mahoganize',
#  'sickish',
#  'metalization',
#  'pristine',
#  'youthwort',
#  'rehearser',
#  'reoffer',
#  'mignon',
#  'distemperature',
#  'interdistrict',
#  'pilastering',
#  'archapostate',
#  'lucernariidae',
#  'frockmaker',
#  'perspirability',
#  'optableness',
#  'agrufe',
#  'agnostic',
#  'chetty',
#  'incorporator',
#  'nondeception',
#  'properly',
#  'reabsolve',
#  'cabbage',
#  'antiromantic',
#  'archipelagic',
#  'mithridatic',
#  'pythios',
#  'goffering',
#  'reintimate',
#  'chouquette',
#  'overchurch',
#  'unstuff',
#  'upswell',
#  'undiscerning',
#  'inconscient',
#  'realizing',
#  'tabaxir',
#  'atlantides',
#  'svantovit',
#  'nonconfirmation',
#  'unduly',
#  'outbeggar',
#  'policemanism',
#  'overspeedy',
#  'autofecundation',
#  'serapis',
#  'metallify',
#  'phlegmatist',
#  'fruiteress',
#  'kallege',
#  'reboisement',
#  'skeenyie',
#  'frowzily',
#  'ditriglyphic',
#  'pulpectomy',
#  'cummerbund',
#  'manzanita',
#  'praecordium',
#  'microphallus',
#  'prematch',
#  'unselfishly',
#  'prouniformity',
#  'spicule',
#  'satirizable',
#  'hypoptosis',
#  'inconceivably',
#  'uncontradictable',
#  'underhammer',
#  'redivorcement',
#  'irrefrangibility',
#  'tailoress',
#  'allokurtic',
#  'germanomania',
#  'mauser',
#  'monopteral',
#  'astigmometry',
#  'jurisprudentially',
#  'quadriplicate',
#  'chirrupy',
#  'romanhood',
#  'exquisiteness',
#  'fungilliform',
#  'parachutism',
#  'cremone',
#  'arson',
#  'pharyngopalatinus',
#  'clericalist',
#  'postform',
#  'jacent',
#  'bursiculate',
#  'tuskless',
#  'nullifier',
#  'sarkless',
#  'prereject',
#  'mess',
#  'tricinium',
#  'celeomorphae',
#  'intraorganization',
#  'gail',
#  'inculcation',
#  'tungstosilicic',
#  'unremembrance',
#  'wayfarer',
#  'napa',
#  'engrained',
#  'neuroclonic',
#  'featheriness',
#  'pedestrially',
#  'agitation',
#  'unjesuitical',
#  'faeroe',
#  'xiphuous',
#  'acetabular',
#  'aerodyne',
#  'zelator',
#  'hordeiform',
#  'ferroaluminum',
#  'submental',
#  'tellina',
#  'consignificant',
#  'angaralite',
#  'maratist',
#  'hyporcheme',
#  'anatifa',
#  'altarpiece',
#  'pennatula',
#  'katipunan',
#  'pfeffernuss',
#  'edingtonite',
#  'whizzle',
#  'adoperate',
#  'psychotrine',
#  'unanswerably',
#  'transferableness',
#  'valleyite',
#  'greatish',
#  'bicentennial',
#  'trochaic',
#  'titleholder',
#  'yowie',
#  'reimmigrant',
#  'benevolentness',
#  'marjoram',
#  'heptaspermous',
#  'automacy',
#  'betters',
#  'indefinitively',
#  'reliquefy',
#  'credenda',
#  'solidifiable',
#  'tritencephalon',
#  'cashierment',
#  'wayfare',
#  'whillaballoo',
#  'cathartes',
#  'pantelephone',
#  'denarcotization',
#  'stolenness',
#  'poroseness',
#  'claretian',
#  'postmyxedematous',
#  'tetrole',
#  'gnatter',
#  'ostensive',
#  'thrombogenic',
#  'metaspermic',
#  'polyadenia',
#  'triverbial',
#  'atlantic',
#  'bladderlike',
#  'lochiocyte',
#  'reve',
#  'hitchproof',
#  'potboy',
#  'benzoglycolic',
#  'bromuret',
#  'isocyanine',
#  'serean',
#  'syndesmoplasty',
#  'tauromachic',
#  'unreforming',
#  'lineograph',
#  'refusing',
#  'speleologist',
#  'dispersion',
#  'waxmaking',
#  'cyllenian',
#  'tututni',
#  'auganite',
#  'epidiascope',
#  'inbent',
#  'siliceocalcareous',
#  'truish',
#  'scored',
#  'abba',
#  'cortisone',
#  'crystolon',
#  'metabiotically',
#  'derivedly',
#  'nonfatty',
#  'recessiveness',
#  'leafless',
#  'scyphozoa',
#  'tetramerous',
#  'twiningly',
#  'feedback',
#  'upright',
#  'leadenhearted',
#  'felsitic',
#  'proinnovationist',
#  'protistology',
#  'retrosplenic',
#  'stokavian',
#  'enchytraeus',
#  'sermuncle',
#  'pincian',
#  'accommodableness',
#  'subdivisible',
#  'bandboxy',
#  'preparatory',
#  'ureterolithotomy',
#  'osmidrosis',
#  'bilin',
#  'questful',
#  'puritaness',
#  'postludium',
#  'menophania',
#  'boride',
#  'misimpression',
#  'laryngic',
#  'unassenting',
#  'overindustrialize',
#  'contrarational',
#  'procurrent',
#  'protogaster',
#  'pliable',
#  'sensitivity',
#  'unsoftening',
#  'theriodonta',
#  'macerate',
#  'patriarchically',
#  'proexposure',
#  'lodgeful',
#  'amphigenously',
#  'domestication',
#  'marquisette',
#  'visit',
#  'nonprobable',
#  'stereoscopic',
#  'shopbreaking',
#  'bedribble',
#  'spermoviduct',
#  'territoried',
#  'counterirritation',
#  'prepollency',
#  'nitramino',
#  'granitelike',
#  'ansar',
#  'serosanguineous',
#  'microgeology',
#  'hexosamine',
#  'prosiphonate',
#  'shadowbox',
#  'sife',
#  'postmillenarianism',
#  'incineration',
#  'mucorine',
#  'pandorea',
#  'papillule',
#  'upheal',
#  'conservative',
#  'zoned',
#  'percentaged',
#  'unserenaded',
#  'swordfish',
#  'entoprocta',
#  'colonoscope',
#  'carefully',
#  'appositionally',
#  'splutterer',
#  'gossipingly',
#  'naturism',
#  'unrepose',
#  'geared',
#  'creepmousy',
#  'graphiola',
#  'decretory',
#  'perniciously',
#  'subintent',
#  'attractable',
#  'zooscopic',
#  'backhatch',
#  'owing',
#  'electrification',
#  'viscously',
#  'widespreadness',
#  'praxitelean',
#  'inaidable',
#  'lumpiness',
#  'pajock',
#  'sulphite',
#  'extrinsicate',
#  'interscribe',
#  'puritandom',
#  'dumfounder',
#  'sang',
#  'boread',
#  'inextinguishable',
#  'bebothered',
#  'photomicrogram',
#  'wretched',
#  'heliocentricism',
#  'cistercianism',
#  'decatize',
#  'salespeople',
#  'bugwort',
#  'mystical',
#  'siphonophorous',
#  'unvulgarize',
#  'parley',
#  'trochodendron',
#  'esugarization',
#  'brachygraphical',
#  'cyclic',
#  'unscreenably',
#  'prolegomenon',
#  'galoisian',
#  'adroit',
#  'arthrometer',
#  'peele',
#  'site',
#  'snowish',
#  'chowk',
#  'nettlefire',
#  'precipitately',
#  'delayingly',
#  'hosiomartyr',
#  'mercaptal',
#  'nonoecumenic',
#  'tenectomy',
#  'comprehense',
#  'cambial',
#  'universanimous',
#  'elasticin',
#  'recongeal',
#  'laterifolious',
#  'supersincerity',
#  'elaphurus',
#  'nonulcerous',
#  'quakeful',
#  'baywood',
#  'brimmingly',
#  'hyperthermy',
#  'contrafagotto',
#  'appear',
#  'entablatured',
#  'braggingly',
#  'presuspend',
#  'cunas',
#  'dispiteousness',
#  'tarbet',
#  'watchtower',
#  'changos',
#  'polydermy',
#  'spirometry',
#  'indetectable',
#  'chrome',
#  'immatriculation',
#  'scabbling',
#  'beechen',
#  'sideburns',
#  'gangism',
#  'counterinvective',
#  'model',
#  'dennis',
#  'omoideum',
#  'overstock',
#  'pediatrics',
#  'bebelted',
#  'gelatinochloride',
#  'plumeous',
#  'headlongwise',
#  'overconcerned',
#  'redivive',
#  'overburst',
#  'aldine',
#  'dendraspis',
#  'mimic',
#  'unshaveable',
#  'helleborus',
#  'antiblue',
#  'bowieful',
#  'crutchlike',
#  'discommodious',
#  'commodity',
#  'specificly',
#  'squalid',
#  ...}

# %%
# ...turned into a sorted list
words = sorted(line.strip().lower() for line in open('words.txt', 'r'))

# %%
words
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abassin',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
#  'abator',
#  'abattoir',
#  'abatua',
#  'abature',
#  'abave',
#  'abaxial',
#  'abaxile',
#  'abaze',
#  'abb',
#  'abba',
#  'abbacomes',
#  'abbacy',
#  'abbadide',
#  'abbas',
#  'abbasi',
#  'abbassi',
#  'abbasside',
#  'abbatial',
#  'abbatical',
#  'abbess',
#  'abbey',
#  'abbeystede',
#  'abbie',
#  'abbot',
#  'abbotcy',
#  'abbotnullius',
#  'abbotship',
#  'abbreviate',
#  'abbreviately',
#  'abbreviation',
#  'abbreviator',
#  'abbreviatory',
#  'abbreviature',
#  'abby',
#  'abcoulomb',
#  'abdal',
#  'abdat',
#  'abderian',
#  'abderite',
#  'abdest',
#  'abdicable',
#  'abdicant',
#  'abdicate',
#  'abdication',
#  'abdicative',
#  'abdicator',
#  'abdiel',
#  'abditive',
#  'abditory',
#  'abdomen',
#  'abdominal',
#  'abdominales',
#  'abdominalian',
#  'abdominally',
#  'abdominoanterior',
#  'abdominocardiac',
#  'abdominocentesis',
#  'abdominocystic',
#  'abdominogenital',
#  'abdominohysterectomy',
#  'abdominohysterotomy',
#  'abdominoposterior',
#  'abdominoscope',
#  'abdominoscopy',
#  'abdominothoracic',
#  'abdominous',
#  'abdominovaginal',
#  'abdominovesical',
#  'abduce',
#  'abducens',
#  'abducent',
#  'abduct',
#  'abduction',
#  'abductor',
#  'abe',
#  'abeam',
#  'abear',
#  'abearance',
#  'abecedarian',
#  'abecedarium',
#  'abecedary',
#  'abed',
#  'abeigh',
#  'abel',
#  'abele',
#  'abelia',
#  'abelian',
#  'abelicea',
#  'abelite',
#  'abelite',
#  'abelmoschus',
#  'abelmosk',
#  'abelonian',
#  'abeltree',
#  'abencerrages',
#  'abenteric',
#  'abepithymia',
#  'aberdeen',
#  'aberdevine',
#  'aberdonian',
#  'aberia',
#  'aberrance',
#  'aberrancy',
#  'aberrant',
#  'aberrate',
#  'aberration',
#  'aberrational',
#  'aberrator',
#  'aberrometer',
#  'aberroscope',
#  'aberuncator',
#  'abet',
#  'abetment',
#  'abettal',
#  'abettor',
#  'abevacuation',
#  'abey',
#  'abeyance',
#  'abeyancy',
#  'abeyant',
#  'abfarad',
#  'abhenry',
#  'abhiseka',
#  'abhominable',
#  'abhor',
#  'abhorrence',
#  'abhorrency',
#  'abhorrent',
#  'abhorrently',
#  'abhorrer',
#  'abhorrible',
#  'abhorring',
#  'abhorson',
#  'abidal',
#  'abidance',
#  'abide',
#  'abider',
#  'abidi',
#  'abiding',
#  'abidingly',
#  'abidingness',
#  'abie',
#  'abies',
#  'abietate',
#  'abietene',
#  'abietic',
#  'abietin',
#  'abietineae',
#  'abietineous',
#  'abietinic',
#  'abiezer',
#  'abigail',
#  'abigail',
#  'abigailship',
#  'abigeat',
#  'abigeus',
#  'abilao',
#  'ability',
#  'abilla',
#  'abilo',
#  'abintestate',
#  'abiogenesis',
#  'abiogenesist',
#  'abiogenetic',
#  'abiogenetical',
#  'abiogenetically',
#  'abiogenist',
#  'abiogenous',
#  'abiogeny',
#  'abiological',
#  'abiologically',
#  'abiology',
#  'abiosis',
#  'abiotic',
#  'abiotrophic',
#  'abiotrophy',
#  'abipon',
#  'abir',
#  'abirritant',
#  'abirritate',
#  'abirritation',
#  'abirritative',
#  'abiston',
#  'abitibi',
#  'abiuret',
#  'abject',
#  'abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'abjoint',
#  'abjudge',
#  'abjudicate',
#  'abjudication',
#  'abjunction',
#  'abjunctive',
#  'abjuration',
#  'abjuratory',
#  'abjure',
#  'abjurement',
#  'abjurer',
#  'abkar',
#  'abkari',
#  'abkhas',
#  'abkhasian',
#  'ablach',
#  'ablactate',
#  'ablactation',
#  'ablare',
#  'ablastemic',
#  'ablastous',
#  'ablate',
#  'ablation',
#  'ablatitious',
#  'ablatival',
#  'ablative',
#  'ablator',
#  'ablaut',
#  'ablaze',
#  'able',
#  'ableeze',
#  'ablegate',
#  'ableness',
#  'ablepharia',
#  'ablepharon',
#  'ablepharous',
#  'ablepharus',
#  'ablepsia',
#  'ableptical',
#  'ableptically',
#  'abler',
#  'ablest',
#  'ablewhackets',
#  'ablins',
#  'abloom',
#  'ablow',
#  'ablude',
#  'abluent',
#  'ablush',
#  'ablution',
#  'ablutionary',
#  'abluvion',
#  'ably',
#  'abmho',
#  'abnaki',
#  'abnegate',
#  'abnegation',
#  'abnegative',
#  'abnegator',
#  'abner',
#  'abnerval',
#  'abnet',
#  'abneural',
#  'abnormal',
#  'abnormalism',
#  'abnormalist',
#  'abnormality',
#  'abnormalize',
#  'abnormally',
#  'abnormalness',
#  'abnormity',
#  'abnormous',
#  'abnumerable',
#  'abo',
#  'aboard',
#  'abobra',
#  'abode',
#  'abodement',
#  'abody',
#  'abohm',
#  'aboil',
#  'abolish',
#  'abolisher',
#  'abolishment',
#  'abolition',
#  'abolitionary',
#  'abolitionism',
#  'abolitionist',
#  'abolitionize',
#  'abolla',
#  'aboma',
#  'abomasum',
#  'abomasus',
#  'abominable',
#  'abominableness',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abominator',
#  'abomine',
#  'abongo',
#  'aboon',
#  'aborad',
#  'aboral',
#  'aborally',
#  'abord',
#  'aboriginal',
#  'aboriginality',
#  'aboriginally',
#  'aboriginary',
#  'aborigine',
#  'abort',
#  'aborted',
#  'aborticide',
#  'abortient',
#  'abortifacient',
#  'abortin',
#  'abortion',
#  'abortional',
#  'abortionist',
#  'abortive',
#  'abortively',
#  'abortiveness',
#  'abortus',
#  'abouchement',
#  'abound',
#  'abounder',
#  'abounding',
#  'aboundingly',
#  'about',
#  'abouts',
#  'above',
#  'aboveboard',
#  'abovedeck',
#  'aboveground',
#  'aboveproof',
#  'abovestairs',
#  'abox',
#  'abracadabra',
#  'abrachia',
#  'abradant',
#  'abrade',
#  'abrader',
#  'abraham',
#  'abrahamic',
#  'abrahamidae',
#  'abrahamite',
#  'abrahamitic',
#  'abraid',
#  'abram',
#  'abramis',
#  'abranchial',
#  'abranchialism',
#  'abranchian',
#  'abranchiata',
#  'abranchiate',
#  'abranchious',
#  'abrasax',
#  'abrase',
#  'abrash',
#  'abrasiometer',
#  'abrasion',
#  'abrasive',
#  'abrastol',
#  'abraum',
#  'abraxas',
#  'abreact',
#  'abreaction',
#  'abreast',
#  'abrenounce',
#  'abret',
#  'abrico',
#  'abridge',
#  'abridgeable',
#  'abridged',
#  'abridgedly',
#  'abridger',
#  'abridgment',
#  'abrim',
#  'abrin',
#  'abristle',
#  'abroach',
#  'abroad',
#  'abrocoma',
#  'abrocome',
#  'abrogable',
#  'abrogate',
#  'abrogation',
#  'abrogative',
#  'abrogator',
#  'abroma',
#  'abronia',
#  'abrook',
#  'abrotanum',
#  'abrotine',
#  'abrupt',
#  'abruptedly',
#  'abruption',
#  'abruptly',
#  'abruptness',
#  'abrus',
#  'absalom',
#  'absampere',
#  'absaroka',
#  'absarokite',
#  'abscess',
#  'abscessed',
#  'abscession',
#  'abscessroot',
#  'abscind',
#  'abscise',
#  'abscision',
#  'absciss',
#  'abscissa',
#  'abscissae',
#  'abscisse',
#  'abscission',
#  'absconce',
#  'abscond',
#  'absconded',
#  'abscondedly',
#  'abscondence',
#  'absconder',
#  'absconsa',
#  'abscoulomb',
#  'absence',
#  'absent',
#  'absentation',
#  'absentee',
#  'absenteeism',
#  'absenteeship',
#  'absenter',
#  'absently',
#  'absentment',
#  'absentmindedly',
#  'absentness',
#  'absfarad',
#  'abshenry',
#  'absi',
#  'absinthe',
#  'absinthial',
#  'absinthian',
#  'absinthiate',
#  'absinthic',
#  'absinthin',
#  'absinthine',
#  'absinthism',
#  'absinthismic',
#  'absinthium',
#  'absinthol',
#  'absit',
#  'absmho',
#  'absohm',
#  'absolute',
#  'absolutely',
#  'absoluteness',
#  'absolution',
#  'absolutism',
#  'absolutist',
#  'absolutistic',
#  'absolutistically',
#  'absolutive',
#  'absolutization',
#  'absolutize',
#  'absolutory',
#  'absolvable',
#  'absolvatory',
#  'absolve',
#  'absolvent',
#  'absolver',
#  'absolvitor',
#  'absolvitory',
#  'absonant',
#  'absonous',
#  'absorb',
#  'absorbability',
#  'absorbable',
#  'absorbed',
#  'absorbedly',
#  'absorbedness',
#  'absorbefacient',
#  'absorbency',
#  'absorbent',
#  'absorber',
#  'absorbing',
#  'absorbingly',
#  'absorbition',
#  'absorpt',
#  'absorptance',
#  'absorptiometer',
#  'absorptiometric',
#  'absorption',
#  'absorptive',
#  'absorptively',
#  'absorptiveness',
#  'absorptivity',
#  'absquatulate',
#  'abstain',
#  'abstainer',
#  'abstainment',
#  'abstemious',
#  'abstemiously',
#  'abstemiousness',
#  'abstention',
#  'abstentionist',
#  'abstentious',
#  'absterge',
#  'abstergent',
#  'abstersion',
#  'abstersive',
#  'abstersiveness',
#  'abstinence',
#  'abstinency',
#  'abstinent',
#  'abstinential',
#  'abstinently',
#  'abstract',
#  'abstracted',
#  'abstractedly',
#  'abstractedness',
#  'abstracter',
#  'abstraction',
#  'abstractional',
#  'abstractionism',
#  'abstractionist',
#  'abstractitious',
#  'abstractive',
#  'abstractively',
#  'abstractiveness',
#  'abstractly',
#  'abstractness',
#  'abstractor',
#  'abstrahent',
#  'abstricted',
#  'abstriction',
#  'abstruse',
#  'abstrusely',
#  'abstruseness',
#  'abstrusion',
#  'abstrusity',
#  'absume',
#  'absumption',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'absvolt',
#  'absyrtus',
#  'abterminal',
#  'abthain',
#  'abthainrie',
#  'abthainry',
#  'abthanage',
#  'abu',
#  'abu',
#  'abucco',
#  'abulia',
#  'abulic',
#  'abulomania',
#  'abuna',
#  'abundance',
#  'abundancy',
#  'abundant',
#  'abundantia',
#  'abundantly',
#  'abura',
#  'aburabozu',
#  'aburban',
#  'aburst',
#  'aburton',
#  'abusable',
#  'abuse',
#  'abusedly',
#  'abusee',
#  'abuseful',
#  'abusefully',
#  'abusefulness',
#  'abuser',
#  'abusion',
#  'abusious',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'abut',
#  'abuta',
#  'abutilon',
#  'abutment',
#  'abuttal',
#  'abutter',
#  'abutting',
#  'abuzz',
#  'abvolt',
#  'abwab',
#  'aby',
#  'abysm',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'abyssal',
#  'abyssinian',
#  'abyssobenthonic',
#  'abyssolith',
#  'abyssopelagic',
#  'acacatechin',
#  'acacatechol',
#  'acacetin',
#  'acacia',
#  'acacian',
#  'acaciin',
#  'acacin',
#  'academe',
#  'academial',
#  'academian',
#  'academic',
#  'academic',
#  'academical',
#  'academically',
#  'academicals',
#  'academician',
#  'academicism',
#  'academism',
#  'academist',
#  'academite',
#  'academization',
#  'academize',
#  'academus',
#  'academy',
#  'acadia',
#  'acadialite',
#  'acadian',
#  'acadie',
#  'acaena',
#  'acajou',
#  'acaleph',
#  'acalepha',
#  'acalephae',
#  'acalephan',
#  'acalephoid',
#  'acalycal',
#  'acalycine',
#  'acalycinous',
#  'acalyculate',
#  'acalypha',
#  'acalypterae',
#  'acalyptrata',
#  'acalyptratae',
#  'acalyptrate',
#  'acamar',
#  'acampsia',
#  'acana',
#  'acanaceous',
#  'acanonical',
#  'acanth',
#  'acantha',
#  'acanthaceae',
#  'acanthaceous',
#  'acanthad',
#  'acantharia',
#  'acanthia',
#  'acanthial',
#  'acanthin',
#  'acanthine',
#  'acanthion',
#  'acanthite',
#  'acanthocarpous',
#  'acanthocephala',
#  'acanthocephalan',
#  'acanthocephali',
#  'acanthocephalous',
#  'acanthocereus',
#  'acanthocladous',
#  'acanthodea',
#  'acanthodean',
#  'acanthodei',
#  'acanthodes',
#  'acanthodian',
#  'acanthodidae',
#  'acanthodii',
#  'acanthodini',
#  'acanthoid',
#  'acantholimon',
#  'acanthological',
#  'acanthology',
#  'acantholysis',
#  'acanthoma',
#  'acanthomeridae',
#  'acanthon',
#  'acanthopanax',
#  'acanthophis',
#  'acanthophorous',
#  'acanthopod',
#  'acanthopodous',
#  'acanthopomatous',
#  'acanthopore',
#  'acanthopteran',
#  'acanthopteri',
#  'acanthopterous',
#  'acanthopterygian',
#  'acanthopterygii',
#  'acanthosis',
#  'acanthous',
#  'acanthuridae',
#  'acanthurus',
#  'acanthus',
#  'acapnia',
#  'acapnial',
#  'acapsular',
#  'acapu',
#  'acapulco',
#  'acara',
#  'acarapis',
#  'acardia',
#  'acardiac',
#  'acari',
#  'acarian',
#  'acariasis',
#  'acaricidal',
#  'acaricide',
#  'acarid',
#  'acarida',
#  'acaridea',
#  'acaridean',
#  'acaridomatium',
#  'acariform',
#  'acarina',
#  'acarine',
#  'acarinosis',
#  'acarocecidium',
#  'acarodermatitis',
#  'acaroid',
#  'acarol',
#  'acarologist',
#  'acarology',
#  'acarophilous',
#  'acarophobia',
#  'acarotoxic',
#  'acarpelous',
#  'acarpous',
#  'acarus',
#  'acastus',
#  'acatalectic',
#  'acatalepsia',
#  'acatalepsy',
#  'acataleptic',
#  'acatallactic',
#  'acatamathesia',
#  'acataphasia',
#  'acataposis',
#  'acatastasia',
#  'acatastatic',
#  'acate',
#  'acategorical',
#  'acatery',
#  'acatharsia',
#  'acatharsy',
#  'acatholic',
#  'acaudal',
#  'acaudate',
#  'acaulescent',
#  'acauline',
#  'acaulose',
#  'acaulous',
#  'acca',
#  'accede',
#  'accedence',
#  'acceder',
#  'accelerable',
#  'accelerando',
#  'accelerant',
#  'accelerate',
#  'accelerated',
#  'acceleratedly',
#  'acceleration',
#  'accelerative',
#  'accelerator',
#  'acceleratory',
#  'accelerograph',
#  'accelerometer',
#  'accend',
#  'accendibility',
#  'accendible',
#  'accension',
#  'accensor',
#  'accent',
#  'accentless',
#  'accentor',
#  'accentuable',
#  'accentual',
#  'accentuality',
#  'accentually',
#  'accentuate',
#  'accentuation',
#  'accentuator',
#  'accentus',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptableness',
#  'acceptably',
#  'acceptance',
#  'acceptancy',
#  'acceptant',
#  'acceptation',
#  'accepted',
#  'acceptedly',
#  'accepter',
#  'acceptilate',
#  'acceptilation',
#  'acception',
#  'acceptive',
#  'acceptor',
#  'acceptress',
#  'accerse',
#  'accersition',
#  'accersitor',
#  'access',
#  'accessarily',
#  'accessariness',
#  'accessary',
#  'accessaryship',
#  'accessibility',
#  'accessible',
#  'accessibly',
#  'accession',
#  'accessional',
#  'accessioner',
#  'accessive',
#  'accessively',
#  'accessless',
#  'accessorial',
#  'accessorily',
#  'accessoriness',
#  'accessorius',
#  'accessory',
#  'accidence',
#  'accidency',
#  'accident',
#  'accidental',
#  'accidentalism',
#  'accidentalist',
#  'accidentality',
#  'accidentally',
#  'accidentalness',
#  'accidented',
#  'accidential',
#  'accidentiality',
#  'accidently',
#  'accidia',
#  'accidie',
#  'accinge',
#  'accipient',
#  'accipiter',
#  'accipitral',
#  'accipitrary',
#  'accipitres',
#  'accipitrine',
#  'accismus',
#  'accite',
#  'acclaim',
#  'acclaimable',
#  'acclaimer',
#  'acclamation',
#  'acclamator',
#  'acclamatory',
#  'acclimatable',
#  'acclimatation',
#  'acclimate',
#  'acclimatement',
#  'acclimation',
#  'acclimatizable',
#  'acclimatization',
#  'acclimatize',
#  'acclimatizer',
#  'acclimature',
#  'acclinal',
#  'acclinate',
#  'acclivitous',
#  'acclivity',
#  'acclivous',
#  'accloy',
#  'accoast',
#  'accoil',
#  'accolade',
#  'accoladed',
#  'accolated',
#  'accolent',
#  'accolle',
#  'accombination',
#  'accommodable',
#  'accommodableness',
#  'accommodate',
#  'accommodately',
#  'accommodateness',
#  'accommodating',
#  'accommodatingly',
#  'accommodation',
#  'accommodational',
#  'accommodative',
#  'accommodativeness',
#  'accommodator',
#  'accompanier',
#  'accompaniment',
#  'accompanimental',
#  'accompanist',
#  'accompany',
#  'accompanyist',
#  'accompletive',
#  'accomplice',
#  'accompliceship',
#  'accomplicity',
#  'accomplish',
#  'accomplishable',
#  'accomplished',
#  'accomplisher',
#  'accomplishment',
#  'accomplisht',
#  'accompt',
#  'accord',
#  'accordable',
#  'accordance',
#  'accordancy',
#  'accordant',
#  ...]

# %%
# return a list of all lines from an open file 
words = sorted{lines.strip().lowercase() for line in open('francais.txt', 'r', encoding='latin1')}
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_4120\1463065106.py", line 2
#     words = sorted{lines.strip().lowercase() for line in open('francais.txt', 'r', encoding='latin1')}
#                   ^
# SyntaxError: invalid syntax
